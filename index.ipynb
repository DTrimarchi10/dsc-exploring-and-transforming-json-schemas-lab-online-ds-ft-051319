# %% [markdown]
# # Exploring and Transforming JSON Schemas

# %% [markdown]
# # Introduction
#
# In this lesson, you'll formalize how to explore a JSON file whose structure and schema is unknown to you. This often happens in practice when you are handed a file or stumble upon one with little documentation.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Explore unknown JSON schemas
# * Access and manipulate data inside a JSON file
# * Convert JSON to alternative data formats

# %% [markdown]
# ## Loading the JSON file
#
# Load the data from the file disease_data.json.

# %%
#Your code here 
import json
f=open('disease_data.json')
data = json.load(f)
data['meta'].keys()
# Out:
# dict_keys(['view'])

# %% [markdown]
# ## Explore the first and second levels of the schema hierarchy

# %%
#Your code here
for key in data['meta']['view'].keys():
    print(key, type(data['meta']['view'][key]))
    
len(data['meta']['view'])
# Out:
# id <class 'str'>
# name <class 'str'>
# attribution <class 'str'>
# attributionLink <class 'str'>
# averageRating <class 'int'>
# category <class 'str'>
# createdAt <class 'int'>
# description <class 'str'>
# displayType <class 'str'>
# downloadCount <class 'int'>
# hideFromCatalog <class 'bool'>
# hideFromDataJson <class 'bool'>
# indexUpdatedAt <class 'int'>
# licenseId <class 'str'>
# newBackend <class 'bool'>
# numberOfComments <class 'int'>
# oid <class 'int'>
# provenance <class 'str'>
# publicationAppendEnabled <class 'bool'>
# publicationDate <class 'int'>
# publicationGroup <class 'int'>
# publicationStage <class 'str'>
# rowClass <class 'str'>
# rowsUpdatedAt <class 'int'>
# rowsUpdatedBy <class 'str'>
# tableId <class 'int'>
# totalTimesRated <class 'int'>
# viewCount <class 'int'>
# viewLastModified <class 'int'>
# viewType <class 'str'>
# columns <class 'list'>
# grants <class 'list'>
# license <class 'dict'>
# metadata <class 'dict'>
# owner <class 'dict'>
# query <class 'dict'>
# rights <class 'list'>
# tableAuthor <class 'dict'>
# tags <class 'list'>
# flags <class 'list'>
# 40

# %% [markdown]
# ## Convert to a DataFrame
#
# Create a DataFrame from the JSON file. Be sure to retrive the column names for the dataframe. (Search within the 'meta' key of the master dictionary.) The DataFrame should include all 42 columns.

# %%
import pandas as pd

# %%
#Your code here
df = pd.DataFrame(data['data'])
df.head()
# Out:
#    0                                     1   2           3       4   \
# 0   1  FF49C41F-CE8D-46C4-9164-653B1227CF6F   1  1527194521  959778
# 1   2  F4468C3D-340A-4CD2-84A3-DF554DFF065E   2  1527194521  959778
# 2   3  65609156-A343-4869-B03F-2BA62E96AC19   3  1527194521  959778
# 3   4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3   4  1527194521  959778
# 4   5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B   5  1527194521  959778
#
#            5       6     7     8     9   ...   32   33      34       35  \
# 0  1527194521  959778  None  2016  2016  ...   59  ALC  ALC2_2  CRDPREV
# 1  1527194521  959778  None  2016  2016  ...   01  ALC  ALC2_2  CRDPREV
# 2  1527194521  959778  None  2016  2016  ...   02  ALC  ALC2_2  CRDPREV
# 3  1527194521  959778  None  2016  2016  ...   04  ALC  ALC2_2  CRDPREV
# 4  1527194521  959778  None  2016  2016  ...   05  ALC  ALC2_2  CRDPREV
#
#         36   37    38    39    40    41
# 0  OVERALL  OVR  None  None  None  None
# 1  OVERALL  OVR  None  None  None  None
# 2  OVERALL  OVR  None  None  None  None
# 3  OVERALL  OVR  None  None  None  None
# 4  OVERALL  OVR  None  None  None  None
#
# [5 rows x 42 columns]

# %%
df.columns = [x['name'] for x in data['meta']['view']['columns']]
df.head()
# Out:
#    sid                                    id  position  created_at  \
# 0    1  FF49C41F-CE8D-46C4-9164-653B1227CF6F         1  1527194521
# 1    2  F4468C3D-340A-4CD2-84A3-DF554DFF065E         2  1527194521
# 2    3  65609156-A343-4869-B03F-2BA62E96AC19         3  1527194521
# 3    4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3         4  1527194521
# 4    5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B         5  1527194521
#
#   created_meta  updated_at updated_meta  meta YearStart YearEnd  \
# 0       959778  1527194521       959778  None      2016    2016
# 1       959778  1527194521       959778  None      2016    2016
# 2       959778  1527194521       959778  None      2016    2016
# 3       959778  1527194521       959778  None      2016    2016
# 4       959778  1527194521       959778  None      2016    2016
#
#          ...        LocationID TopicID QuestionID DataValueTypeID  \
# 0        ...                59     ALC     ALC2_2         CRDPREV
# 1        ...                01     ALC     ALC2_2         CRDPREV
# 2        ...                02     ALC     ALC2_2         CRDPREV
# 3        ...                04     ALC     ALC2_2         CRDPREV
# 4        ...                05     ALC     ALC2_2         CRDPREV
#
#   StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 0                   OVERALL               OVR                      None
# 1                   OVERALL               OVR                      None
# 2                   OVERALL               OVR                      None
# 3                   OVERALL               OVR                      None
# 4                   OVERALL               OVR                      None
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0              None                      None              None
# 1              None                      None              None
# 2              None                      None              None
# 3              None                      None              None
# 4              None                      None              None
#
# [5 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['sid', 'id', 'position', 'created_at', 'created_meta', 'updated_at',
#        'updated_meta', 'meta', 'YearStart', 'YearEnd', 'LocationAbbr',
#        'LocationDesc', 'DataSource', 'Topic', 'Question', 'Response',
#        'DataValueUnit', 'DataValueType', 'DataValue', 'DataValueAlt',
#        'DataValueFootnoteSymbol', 'DatavalueFootnote', 'LowConfidenceLimit',
#        'HighConfidenceLimit', 'StratificationCategory1', 'Stratification1',
#        'StratificationCategory2', 'Stratification2', 'StratificationCategory3',
#        'Stratification3', 'GeoLocation', 'ResponseID', 'LocationID', 'TopicID',
#        'QuestionID', 'DataValueTypeID', 'StratificationCategoryID1',
#        'StratificationID1', 'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
asthma_df = df.copy()
asthma_df = asthma_df.loc[:,['Topic','Question','YearStart', 'YearEnd',
       'DataValueType', 'DataValue', 'DataValueAlt',
       'LocationDesc','LocationID']]
asthma_df = asthma_df.loc[asthma_df.Topic == 'Asthma']
asthma_df.head()
#asthma_df.groupby('LocationDesc')
# Out:
#        Topic                                           Question YearStart  \
# 4725  Asthma  Current asthma prevalence among adults aged >=...      2016
# 5529  Asthma  Current asthma prevalence among adults aged >=...      2016
# 5632  Asthma  Current asthma prevalence among adults aged >=...      2016
# 6777  Asthma  Current asthma prevalence among adults aged >=...      2016
# 7034  Asthma  Current asthma prevalence among adults aged >=...      2016
#
#      YearEnd     DataValueType DataValue DataValueAlt LocationDesc LocationID
# 4725    2016  Crude Prevalence       6.5          6.5     Illinois         17
# 5529    2016  Crude Prevalence       6.7          6.7      Indiana         18
# 5632    2016  Crude Prevalence       5.6          5.6         Iowa         19
# 6777    2016  Crude Prevalence       6.1          6.1       Kansas         20
# 7034    2016  Crude Prevalence       6.9          6.9     Kentucky         21

# %%
asthma_df = asthma_df.loc[asthma_df.Question=='Current asthma prevalence among adults aged >= 18 years']

# %%
asthma_df_1 = asthma_df.loc[(asthma_df.Question=='Current asthma prevalence among adults aged >= 18 years') & 
                            (asthma_df.DataValueType=='Crude Prevalence')]
asthma_df_1['DataValue'] = asthma_df_1['DataValue'].astype(float)
asthma_df_1
# Out:
# /Users/dennistrimarchi/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         Topic                                           Question YearStart  \
# 4725   Asthma  Current asthma prevalence among adults aged >=...      2016
# 5529   Asthma  Current asthma prevalence among adults aged >=...      2016
# 5632   Asthma  Current asthma prevalence among adults aged >=...      2016
# 6777   Asthma  Current asthma prevalence among adults aged >=...      2016
# 7034   Asthma  Current asthma prevalence among adults aged >=...      2016
# 7337   Asthma  Current asthma prevalence among adults aged >=...      2016
# 7428   Asthma  Current asthma prevalence among adults aged >=...      2016
# 7499   Asthma  Current asthma prevalence among adults aged >=...      2016
# 7966   Asthma  Current asthma prevalence among adults aged >=...      2016
# 8114   Asthma  Current asthma prevalence among adults aged >=...      2016
# 8135   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9138   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9218   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9370   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9371   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9372   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9373   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9374   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9375   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9376   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9377   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9378   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9379   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9380   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9381   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9382   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9383   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9384   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9385   Asthma  Current asthma prevalence among adults aged >=...      2016
# 9386   Asthma  Current asthma prevalence among adults aged >=...      2016
# ...       ...                                                ...       ...
# 10144  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10145  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10147  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10148  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10149  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10150  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10151  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10152  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10153  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10154  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10155  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10156  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10157  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10158  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10159  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10160  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10161  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10162  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10163  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10164  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10165  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10166  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10167  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10168  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10169  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10170  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10171  Asthma  Current asthma prevalence among adults aged >=...      2016
# 10172  Asthma  Current asthma prevalence among adults aged >=...      2016
# 
# 10165    2016  Crude Prevalence       14.1         14.1                  Utah
# 10166    2016  Crude Prevalence        NaN         None               Vermont
# 10167    2016  Crude Prevalence        NaN         None              Virginia
# 10168    2016  Crude Prevalence       15.0           15            Washington
# 10169    2016  Crude Prevalence       13.3         13.3         West Virginia
# 10170    2016  Crude Prevalence        NaN         None             Wisconsin
# 10171    2016  Crude Prevalence        NaN         None               Wyoming
# 10172    2016  Crude Prevalence        NaN         None                  Guam
# 10173    2016  Crude Prevalence        NaN         None           Puerto Rico
# 10174    2016  Crude Prevalence        NaN         None        Virgin Islands
#
#       LocationID
# 4725          17
# 5529          18
# 5632          19
# 6777          20
# 7034          21
# 7337          22
# 7428          23
# 7499          24
# 7966          50
# 8114          51
# 8135          12
# 9138          15
# 9218          16
# 9370          59
# 9371          01
# 9372          02
# 9373          04
# 9374          05
# 9375          06
# 9376          08
# 9377          09
# 9378          10
# 9379          11
# 9380          12
# 9381          13
# 9382          15
# 9383          16
# 9384          17
# 9385          18
# 9386          19
# ...          ...
# 10144         28
# 10145         29
# 10147         30
# 10148         31
# 10149         32
# 10150         33
# 10151         34
# 10152         35
# 10153         36
# 10154         37
# 10155         38
# 10156         39
# 10157         40
# 10158         41
# 10159         42
# 10160         44
# 10161         45
# 10162         46
# 10163         47
# 10164         48
# 10165         49
# 10166         50
# 10167         51
# 10168         53
# 10169         54
# 10170         55
# 10171         56
# 10172         66
# 10173         72
# 10174         78
#
# [435 rows x 9 columns]

# %%
asthma_df_1.groupby('LocationDesc')['DataValue'].mean().plot(kind='bar')

# %% [markdown]
# ## Level-Up
# ## Create a bar graph of states with the highest asthma rates for adults age 18+

# %% [markdown]
# ## Level-Up!
# ## Create a function (or class) that returns an outline of the schema structure like this:
# <img src="images/outline.jpg" width="350">
#
# Rules:
# * Your outline should follow the numbering outline above (I, A, 1, a, i).
# * Your outline should be properly indented! (Four spaces or one tab per indentation level.)
# * Your function goes to at least a depth of 5 (Level-up: create a parameter so that the user can specify this)
# * If an entry is a dictionary, list its keys as the subheadings
# * After listing a key name (where applicable) include a space, a dash and the data type of the entry
# * If an entry is a dict or list put in parentheses how many items are in the entry
# * lists will not have key names for their entries (they're just indexed)
# * For subheadings of a list, state their datatypes.
# * If a dictionary or list is more then 5 items long, only show the first 5 (we want to limit our previews); make an arbitrary order choice for dictionaries. (Level-up: Parallel to above; allow user to specify number of items to preview for large subheading collections.)

# %%
# Your code here; you will probably want to define subfunctions.
def print_obj_outline(json_obj):
    return outline

# %%
outline = print_obj_outline(data)

# %%
print(outline) #Your function should produce the following output for this json object (and work for all json files!)
# Out:
# I. root - <class 'dict'> (2 items)
#     A. meta <class 'dict'> (1 items)
#         1. view <class 'dict'> (40 items)
#             a. id <class 'str'>
#             b. name <class 'str'>
#             c. attribution <class 'str'>
#             d. attributionLink <class 'str'>
#             e. averageRating <class 'int'>
#     B. data <class 'list'> (60266 items)
#         1. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         2. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         3. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         4. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         5. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>

# %% [markdown]
# ## Summary
#
# Well done! In this lab you got some extended practice exploring the structure of JSON files and writing a recursive generalized function for outlining a JSON file's schema!
